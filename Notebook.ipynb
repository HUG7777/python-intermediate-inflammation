# %%
filename = "data/small-01.csv"

# %%
from inflammation import models, views

inflammation_data = models.load_data(filename)
view_data = {
    'average': models.daily_mean(inflammation_data),
    'max': models.daily_max(inflammation_data),
    'min': models.daily_min(inflammation_data)
}

views.visualize(view_data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 3
#       1 from inflammation import models, views
# ----> 3 inflammation_data = models.load_data(filename)
#       4 view_data = {
#       5     'average': models.daily_mean(inflammation_data),
#       6     'max': models.daily_max(inflammation_data),
#       7     'min': models.daily_min(inflammation_data)
#       8 }
#      10 views.visualize(view_data)
#
# AttributeError: module 'inflammation.models' has no attribute 'load_data'

# %%
from inflammation import models, views

inflammation_data = models.load_csv(filename)   # ← 修正这里！
view_data = {
    'average': models.daily_mean(inflammation_data),
    'max': models.daily_max(inflammation_data),
    'min': models.daily_min(inflammation_data)
}

views.visualize(view_data)
